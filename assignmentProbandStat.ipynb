# %% [markdown]
# ## Probability and Statistics Assignment

# %% [markdown]
# ### Task 1: Iris Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from scipy import stats
from sklearn import datasets, model_selection, preprocessing

# %%
import pandas as pd
from sklearn import datasets

def load_dataset():
    iris = datasets.load_iris()
    df = pd.DataFrame(iris.data, columns=iris.feature_names)
    df['target'] = iris.target  # Adding target labels
    return df

df = load_dataset()
print(df.head(5))  # Display first 5 rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# #### a. Mean, Median, and Standard deviation

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Compute mean, median, and mode for each feature
mean_values = df.mean()
median_values = df.median()
mode_values = df.mode().iloc[0]  # Get first mode value

# Display results
print("Feature-wise Mean, Median, and Mode:")
for column in df.columns:
    print(f"{column}:")
    print(f"  Mean: {mean_values[column]:.2f}")
    print(f"  Median: {median_values[column]:.2f}")
    print(f"  Mode: {mode_values[column]:.2f}")
    print("-" * 40)
# Out:
# Feature-wise Mean, Median, and Mode:
# sepal length (cm):
#   Mean: 5.84
#   Median: 5.80
#   Mode: 5.00
# ----------------------------------------
# sepal width (cm):
#   Mean: 3.06
#   Median: 3.00
#   Mode: 3.00
# ----------------------------------------
# petal length (cm):
#   Mean: 3.76
#   Median: 4.35
#   Mode: 1.40
# ----------------------------------------
# petal width (cm):
#   Mean: 1.20
#   Median: 1.30
#   Mode: 0.20
# ----------------------------------------

# %% [markdown]
# #### b. Histograms and boxplots for feature distributions.

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Set up figure
plt.figure(figsize=(12, 6))

# Histogram for each feature
for i, column in enumerate(df.columns):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[column], bins=20, color='skyblue', edgecolor='black')
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.title(f"Histogram of {column}")

plt.tight_layout()
plt.show()

# Boxplot for each feature
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, palette="pastel")
plt.xticks(rotation=45)
plt.title("Boxplot of Iris Features")
plt.show()

# %% [markdown]
# ##### Conclusion:
# #####  1.Sepal Length (cm)
# #####  Histogram:The data is concentrated around 5.5–6.0 cm, indicating a common size range for sepal length.
# #####  Boxplot: The feature is fairly normally distributed.
# #####  2.Sepal Width (cm)
# #####  Histogram:There may be variations in sepal width across different species.
# #####  Boxplot:There are some low-value outliers in the sepal width.
# #####  3.Petal Length(cm)
# #####  Histogram:This indicates significant differences in petal lengths between species.
# #####  Boxplot:The feature has high variance, indicating different species have different petal lengths.
# #####  4.Petal Width(cm)
# ##### Histogram:Like petal length, this feature varies significantly across species.
# ##### Boxplot:The petal width distribution is fairly skewed, showing species variation.

# %% [markdown]
# ##### c.

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Compute the correlation matrix
correlation_matrix = df.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Heatmap for visualization
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Iris Features")
plt.show()
# Out:
# Correlation Matrix:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# ##### d.

# %% [markdown]
# Most Correlated Feature
# Petal Length and Petal Width (~0.96)
# Conclusion: These two features are very strongly related. Longer petals usually mean wider petals.
#
# Least Correlated Feature
# Sepal Width and Sepal Length (~-0.12 to 0.09)
# Conclusion: Very weak relationship. Sepal width doesn’t really affect the length of the sepal.

# %% [markdown]
# #### Task 2

# %%
# Given values from the table
A_and_B = 30   # Number of occurrences of A and B
A_and_not_B = 20   # Number of occurrences of A and not B
not_A_and_B = 50   # Number of occurrences of not A and B
not_A_and_not_B = 100  # Number of occurrences of not A and not B

# Total number of occurrences for A, B, and A∩B
P_A_and_B = A_and_B
P_B = A_and_B + not_A_and_B  # Total occurrences of B
P_A = A_and_B + A_and_not_B  # Total occurrences of A

# Conditional probability P(A|B) = P(A ∩ B) / P(B)
P_A_given_B = P_A_and_B / P_B

# Conditional probability P(B|A) = P(A ∩ B) / P(A)
P_B_given_A = P_A_and_B / P_A

# Print results
print(f"P(A|B) = {P_A_given_B:.3f}")
print(f"P(B|A) = {P_B_given_A:.3f}")
# Out:
# P(A|B) = 0.375
# P(B|A) = 0.600

# %% [markdown]
# #### Task 3

# %%
# Given values
P_Spam = 0.2
P_Not_Spam = 0.8
P_Keyword_given_Spam = 0.7
P_Keyword_given_Not_Spam = 0.1

# Step 1: Calculate P(Keyword)
P_Keyword = (P_Keyword_given_Spam * P_Spam) + (P_Keyword_given_Not_Spam * P_Not_Spam)

# Step 2: Apply Bayes' Theorem
P_Spam_given_Keyword = (P_Keyword_given_Spam * P_Spam) / P_Keyword

# Display the result
print(f"P(Spam | Keyword) = {P_Spam_given_Keyword:.3f}")
# Out:
# P(Spam | Keyword) = 0.636

# %% [markdown]
# #### Task 4

# %% [markdown]
# ##### Using Wine Dataset

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

# Load the Diabetes dataset
diabetes = load_diabetes()

# Convert the data into a DataFrame for easier viewing
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

# Display the features
print("Features of the Diabetes dataset:")
print(diabetes_df.columns)
# Out:
# Features of the Diabetes dataset:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

# Load the Diabetes dataset
diabetes = load_diabetes()

# Convert the data into a DataFrame and select features up to 'bp'
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
diabetes_df = diabetes_df[['age', 'sex', 'bmi', 'bp']]

# Compute Q1 (25th percentile) and Q3 (75th percentile) for each feature
Q1 = diabetes_df.quantile(0.25)
Q3 = diabetes_df.quantile(0.75)

# Display the results
print("Q1 (25th percentile) for each feature:")
print(Q1)
print("\nQ3 (75th percentile) for each feature:")
print(Q3)
# Out:
# Q1 (25th percentile) for each feature:
# age   -0.037299
# sex   -0.044642
# bmi   -0.034229
# bp    -0.036656
# Name: 0.25, dtype: float64
#
# Q3 (75th percentile) for each feature:
# age    0.038076
# sex    0.050680
# bmi    0.031248
# bp     0.035644
# Name: 0.75, dtype: float64

# %%
IQR = Q3 - Q1

# Display the results
print("IQR (Interquartile Range) for each feature:")
print(IQR)
# Out:
# IQR (Interquartile Range) for each feature:
# age    0.075375
# sex    0.095322
# bmi    0.065477
# bp     0.072300
# dtype: float64

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

# Load the Diabetes dataset
diabetes = load_diabetes()

# Convert the data into a DataFrame and select features up to 'bp'
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
diabetes_df = diabetes_df[['age', 'sex', 'bmi', 'bp']]

# Compute Q1 (25th percentile) and Q3 (75th percentile)
Q1 = diabetes_df.quantile(0.25)
Q3 = diabetes_df.quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define outliers as values outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Display the lower and upper bounds for outliers
print("Lower bound for outliers:")
print(lower_bound)
print("\nUpper bound for outliers:")
print(upper_bound)
# Out:
# Lower bound for outliers:
# age   -0.150362
# sex   -0.187624
# bmi   -0.132445
# bp    -0.145106
# dtype: float64
#
# Upper bound for outliers:
# age    0.151139
# sex    0.193663
# bmi    0.129464
# bp     0.144094
# dtype: float64

# %%
# Function to remove outliers
def remove_outliers(dataframe):
    # Compute Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = dataframe.quantile(0.25)
    Q3 = dataframe.quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = (dataframe < lower_bound) | (dataframe > upper_bound)

    # Remove rows with outliers
    cleaned_dataframe = dataframe[~outliers.any(axis=1)]

    return cleaned_dataframe

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_diabetes

# Load the Diabetes dataset
diabetes = load_diabetes()

# Convert the data into a DataFrame and select features up to 'bp'
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
diabetes_df = diabetes_df[['age', 'sex', 'bmi', 'bp']]

# Function to remove outliers
def remove_outliers(dataframe):
    # Compute Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = dataframe.quantile(0.25)
    Q3 = dataframe.quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = (dataframe < lower_bound) | (dataframe > upper_bound)

    # Remove rows with outliers
    cleaned_dataframe = dataframe[~outliers.any(axis=1)]

    return cleaned_dataframe

# Remove outliers
cleaned_diabetes_df = remove_outliers(diabetes_df)

# Plot boxplots of features before and after outlier removal
def plot_boxplots_before_after(dataframe, cleaned_dataframe):
    # Create a 1x2 subplot layout
    plt.figure(figsize=(14, 6))
    
    # Boxplot before outlier removal
    plt.subplot(1, 2, 1)
    sns.boxplot(data=dataframe)
    plt.title("Boxplot Before Outlier Removal")
    
    # Boxplot after outlier removal
    plt.subplot(1, 2, 2)
    sns.boxplot(data=cleaned_dataframe)
    plt.title("Boxplot After Outlier Removal")
    
    # Display the plots
    plt.tight_layout()
    plt.show()

# Plotting boxplots for the Diabetes dataset
plot_boxplots_before_after(diabetes_df, cleaned_diabetes_df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Function to plot histograms of features before and after normalization/standardization
def plot_histograms_before_after(dataframe):
    # Select a few features to plot
    features_to_plot = ['age', 'bmi', 'bp']
    
    # Initialize the scalers
    min_max_scaler = MinMaxScaler()
    standard_scaler = StandardScaler()

    # Apply normalization (Min-Max Scaling)
    normalized_df = dataframe.copy()
    normalized_df[features_to_plot] = min_max_scaler.fit_transform(dataframe[features_to_plot])

    # Apply standardization (Z-score Scaling)
    standardized_df = dataframe.copy()
    standardized_df[features_to_plot] = standard_scaler.fit_transform(dataframe[features_to_plot])

    # Create a 3x2 subplot layout
    plt.figure(figsize=(15, 10))
    
    # Before normalization/standardization
    for i, feature in enumerate(features_to_plot, 1):
        plt.subplot(3, 2, i)
        sns.histplot(dataframe[feature], kde=True)
        plt.title(f"Original {feature}")
    
    # After normalization
    for i, feature in enumerate(features_to_plot, 4):
        plt.subplot(3, 2, i)
        sns.histplot(normalized_df[feature], kde=True)
        plt.title(f"Normalized {feature}")
    
    # After standardization
    for i, feature in enumerate(features_to_plot, 7):
        plt.subplot(3, 2, i-3)  # Corrected subplot numbering
        sns.histplot(standardized_df[feature], kde=True)
        plt.title(f"Standardized {feature}")
    
    # Display the plots
    plt.tight_layout()
    plt.show()

# Example usage: Plotting histograms for the Diabetes dataset
plot_histograms_before_after(diabetes_df)
